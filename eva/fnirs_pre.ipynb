# %%
import matplotlib.pyplot as plt
from mne import Epochs, pick_types, events_from_annotations, read_epochs
from mne.io import read_raw_nirx
from mne.preprocessing import ICA
from itertools import compress
from mne.preprocessing.nirs import beer_lambert_law, scalp_coupling_index, source_detector_distances, optical_density
from jupyterthemes.stylefx import set_nb_theme
set_nb_theme('gruvboxd')
# Out:
# <style> div#notebook {
#  font-family: sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #ebdbb2;
#  -webkit-font-smoothing: antialiased !important;
#  padding-top: 25px !important;
# }
# body,
# div.body {
#  font-family: sans-serif;
#  font-size: 13pt;
#  color: #ebdbb2;
#  background-color: #1d2021;
#  background: #1d2021;
#  -webkit-font-smoothing: antialiased !important;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #1d2021;
#  background: #1d2021;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: sans-serif;
#  color: #ebdbb2;
#  -webkit-font-smoothing: antialiased !important;
# }
# a:hover,
# a:focus {
#  color: #fbf1c7;
#  -webkit-font-smoothing: antialiased !important;
# }
# div#maintoolbar {
#  position: absolute;
#  width: 90%;
#  margin-left: -10%;
#  padding-right: 8%;
#  float: left;
#  background: transparent !important;
# }
# #maintoolbar {
#  margin-bottom: -3px;
#  margin-top: 0px;
#  border: 0px;
#  min-height: 27px;
#  padding-top: 2px;
#  padding-bottom: 0px;
# }
# #maintoolbar .container {
#  width: 75%;
#  margin-right: auto;
#  margin-left: auto;
# }
# .list_header,
# div#notebook_list_header.row.list_header {
#  font-size: 14pt;
#  color: #fbf1c7;
#  background-color: transparent;
#  height: 35px;
# }
# i.fa.fa-folder {
#  display: inline-block;
#  font: normal normal normal 14px "FontAwesome";
#  font-family: "FontAwesome" !important;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  font-size: 18px;
#  -moz-osx-font-smoothing: grayscale;
# }
# #running .panel-group .panel .panel-heading {
#  font-size: 14pt;
#  color: #ebdbb2;
#  padding: 8px 8px;
#  background: #1b1d1e;
#  background-color: #1b1d1e;
# }
# #running .panel-group .panel .panel-heading a {
#  font-size: 14pt;
#  color: #ebdbb2;
# }
# #running .panel-group .panel .panel-heading a:focus,
# #running .panel-group .panel .panel-heading a:hover {
#  font-size: 14pt;
#  color: #ebdbb2;
# }
# #running .panel-group .panel .panel-body .list_container .list_item {
#  background: #282828;
#  background-color: #282828;
#  padding: 2px;
#  border-bottom: 2px solid rgba(70,70,70,.5);
# }
# #running .panel-group .panel .panel-body .list_container .list_item:hover {
#  background: #282828;
#  background-color: #282828;
# }
# #running .panel-group .panel .panel-body {
#  padding: 2px;
# }
# button#refresh_running_list {
#  border: none !important;
# }
# button#refresh_cluster_list {
#  border: none !important;
# }
# div.running_list_info.toolbar_info {
#  font-size: 15px;
#  padding: 4px 0 4px 0;
#  margin-top: 5px;
#  margin-bottom: 8px;
#  height: 24px;
#  line-height: 24px;
#  text-shadow: none;
# }
# .list_placeholder {
#  font-weight: normal;
# }
# #tree-selector {
#  padding: 0px;
#  border-color: transparent;
# }
# #project_name > ul > li > a > i.fa.fa-home {
#  color: #d5c4a1;
#  font-size: 17pt;
#  display: inline-block;
#  position: static;
#  padding: 0px 0px;
#  font-weight: normal;
#  text-align: center;
#  vertical-align: text-top;
# }
# .fa-folder:before {
#  color: #83a598;
# }
# .fa-arrow-up:before {
#  font-size: 14px;
# }
# .fa-arrow-down:before {
#  font-size: 14px;
# }
# span#last-modified.btn.btn-xs.btn-default.sort-action:hover .fa,
# span#sort-name.btn.btn-xs.btn-default.sort-action:hover .fa {
#  color: #fe8019;
# }
# .folder_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f07b";
#  color: #83a598;
# }
# .notebook_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f02d";
#  position: relative;
#  color: #b8bb26 !important;
#  top: 0px;
# }
# .file_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f15b";
#  position: relative;
#  top: 0px;
#  color: #d5c4a1 !important;
# }
# #project_name a {
#  display: inline-flex;
#  padding-left: 7px;
#  margin-left: -2px;
#  text-align: -webkit-auto;
#  vertical-align: baseline;
#  font-size: 18px;
# }
# div#notebook_toolbar div.dynamic-instructions {
#  font-family: sans-serif;
#  font-size: 17px;
#  color: #3c3836;
# }
# span#login_widget > .button,
# #logout {
#  font-family: "Proxima Nova", sans-serif;
#  color: #d5c4a1;
#  background: transparent;
#  background-color: transparent;
#  border: 2px solid rgba(70,70,70,.5);
#  font-weight: normal;
#  box-shadow: none;
#  text-shadow: none;
#  border-radius: 3px;
#  margin-right: 10px;
#  padding: 2px 7px;
# }
# span#login_widget > .button:hover,
# #logout:hover {
#  color: #fe8019;
#  background-color: transparent;
#  background: transparent;
#  border: 2px solid #fe8019;
#  background-image: none;
#  box-shadow: none !important;
#  border-radius: 3px;
# }
# span#login_widget > .button:focus,
# #logout:focus,
# span#login_widget > .button.focus,
# #logout.focus,
# span#login_widget > .button:active,
# #logout:active,
# span#login_widget > .button.active,
# #logout.active,
# .open > .dropdown-togglespan#login_widget > .button,
# .open > .dropdown-toggle#logout {
#  color: #83a598;
#  background-color: #d5c4a1;
#  background: #d5c4a1;
#  border-color: #d5c4a1;
#  background-image: none;
#  box-shadow: none !important;
#  border-radius: 2px;
# }
# body > #header #header-container {
#  padding-bottom: 0px;
#  padding-top: 4px;
#  box-sizing: border-box;
#  -moz-box-sizing: border-box;
#  -webkit-box-sizing: border-box;
# }
# body > #header {
#  background: #1d2021;
#  background-color: #1d2021;
#  position: relative;
#  z-index: 100;
# }
# .list_container {
#  font-size: 13pt;
#  color: #ebdbb2;
#  border: none;
#  text-shadow: none !important;
# }
# .list_container > div {
#  border-bottom: 1px solid rgba(70,70,70,.4);
#  font-size: 13pt;
# }
# .list_header > div,
# .list_item > div {
#  padding-top: 6px;
#  padding-bottom: 2px;
#  padding-left: 0px;
# }
# .list_header > div .item_link,
# .list_item > div .item_link {
#  margin-left: -1px;
#  vertical-align: middle;
#  line-height: 22px;
#  font-size: 13pt;
# }
# .item_icon {
#  color: #83a598;
#  font-size: 13pt;
#  vertical-align: middle;
# }
# .list_item input:not([type="checkbox"]) {
#  padding-right: 0px;
#  height: 1.75em;
#  width: 25%;
#  margin: 0px 0 0;
#  margin-top: 0px;
# }
# .list_header > div .item_link,
# .list_item > div .item_link {
#  margin-left: -1px;
#  vertical-align: middle;
#  line-height: 1.5em;
#  font-size: 12pt;
#  display: inline-table;
#  position: static;
# }
# #button-select-all {
#  height: 34px;
#  min-width: 55px;
#  z-index: 0;
#  border: none !important;
#  padding-top: 0px;
#  padding-bottom: 0px;
#  margin-bottom: 0px;
#  margin-top: 0px;
#  left: -3px;
#  border-radius: 0px !important;
# }
# #button-select-all:focus,
# #button-select-all:active:focus,
# #button-select-all.active:focus,
# #button-select-all.focus,
# #button-select-all:active.focus,
# #button-select-all.active.focus {
#  background-color: rgba(70,70,70,.5) !important;
#  background: rgba(70,70,70,.5) !important;
# }
# button#tree-selector-btn {
#  height: 34px;
#  font-size: 12.0pt;
#  border: none;
#  left: 0px;
#  border-radius: 0px !important;
# }
# input#select-all.pull-left.tree-selector {
#  margin-left: 7px;
#  margin-right: 2px;
#  margin-top: 2px;
#  top: 4px;
# }
# input[type="radio"],
# input[type="checkbox"] {
#  margin-top: 1px;
#  line-height: normal;
# }
# .delete-button {
#  border: none !important;
# }
# i.fa.fa-trash {
#  font-size: 13.5pt;
# }
# .list_container a {
#  font-size: 16px;
#  color: #ebdbb2;
#  border: none;
#  text-shadow: none !important;
#  font-weight: normal;
#  font-style: normal;
# }
# div.list_container a:hover {
#  color: #fbf1c7;
# }
# .list_header > div input,
# .list_item > div input {
#  margin-right: 7px;
#  margin-left: 12px;
#  vertical-align: baseline;
#  line-height: 22px;
#  position: relative;
#  top: -1px;
# }
# div.list_item:hover {
#  background-color: rgba(70,70,70,.2);
# }
# .breadcrumb > li {
#  font-size: 12.0pt;
#  color: #ebdbb2;
#  border: none;
#  text-shadow: none !important;
# }
# .breadcrumb > li + li:before {
#  content: "/\00a0";
#  padding: 0px;
#  color: #ebdbb2;
#  font-size: 18px;
# }
# #project_name > .breadcrumb {
#  padding: 0px;
#  margin-bottom: 0px;
#  background-color: transparent;
#  font-weight: normal;
#  margin-top: -2px;
# }
# ul#tabs a {
#  font-family: sans-

# %%
event_dict = {'left': 1, 'right': 2, 'r_pinch': 3, 'rest': 4, 'r_stop': 5}

# %%
raw = read_raw_nirx('nirs')
raw_od = optical_density(raw)
# Out:
# Loading nirs
# Reading 0 ... 16443  =      0.000 ...  2104.704 secs...
# C:\Users\Alberto\AppData\Local\Temp\ipykernel_10084\2156314533.py:1: RuntimeWarning: Extraction of measurement date from NIRX file failed. This can be caused by files saved in certain locales (currently only ['en_US.utf8', 'de_DE', 'fr_FR', 'it_IT'] supported). Please report this as a github issue. The date is being set to January 1st, 2000, instead of '"13 Dec 2022""15:03:36.309"'.
#   raw = read_raw_nirx('nirs')

# %% [markdown]
# Compute Scalp Coupling

# %%
sci = scalp_coupling_index(raw_od)
fig, ax = plt.subplots()
ax.hist(sci)
ax.set(xlabel='Scalp Coupling Index', ylabel='Count', xlim=[0, 1])
# Out:
# [Text(0.5, 0, 'Scalp Coupling Index'), Text(0, 0.5, 'Count'), (0.0, 1.0)]

# %%
raw_od.info['bads'] = list(compress(raw_od.ch_names, sci < 0.6))
raw_od.plot(n_channels=40, duration=200)
print()
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 1920x1017 with 4 Axes>

# %% [markdown]
# Compute Haemoglobin

# %%
raw_hmo = beer_lambert_law(raw_od, ppf=0.1)

# %%
print()
raw_hmo.plot_psd(average=False, dB=False, tmax=1200 ,fmax=2, estimate='power')
# Out:
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 32.768 (s)
# Need more than one channel to make topography for hbo. Disabling interactivity.
# Need more than one channel to make topography for hbr. Disabling interactivity.
# C:\Users\Alberto\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mne\viz\utils.py:137: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x600 with 2 Axes>

# %% [markdown]
# Bandpass filter

# %%
print()
raw_hmo = raw_hmo.filter(0.05, 0.7, h_trans_bandwidth=0.2, l_trans_bandwidth=0.02, n_jobs=8)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.05 - 0.7 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.05
# - Lower transition bandwidth: 0.02 Hz (-6 dB cutoff frequency: 0.04 Hz)
# - Upper passband edge: 0.70 Hz
# - Upper transition bandwidth: 0.20 Hz (-6 dB cutoff frequency: 0.80 Hz)
# - Filter length: 1291 samples (165.248 sec)
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  10 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done  40 out of  40 | elapsed:    3.1s finished

# %%
event, event_id = events_from_annotations(raw_hmo)
epochs = Epochs(raw_hmo, event, event_id=event_dict,
        tmin=-5, tmax=20,
        proj=True, baseline=(-3,0), preload=True,
        detrend=None, verbose=True)
epochs.save('nirs_epo.fif', overwrite=True)
del raw_hmo
del raw_od
# Out:
# Used Annotations descriptions: ['130.0', '134.0', '2.0', '255.0', '4.0']
# Not setting metadata
# 77 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 77 events and 196 original time points ...
# 1 bad epochs dropped

# %%
epochs.plot(n_epochs=5, n_channels=20, scalings=90e-6, events=epochs.events, event_id=epochs.event_id)
print()
# Out:
# <MNEBrowseFigure size 1920x1017 with 4 Axes>

# %% [markdown]
# Removing Artifacts

# %%
epochs = read_epochs('nirs_epo.fif')
epochs.info['bads'] += ['S6_D2 hbr', 'S4_D4 hbr', 'S3_D2 hbr', 'S6_D2 hbo', 'S4_D4 hbo', 'S3_D2 hbo']
epochs.drop([1, 3, 4, 7, 8, 9, 12, 15, 17, 18, 19, 21, 22, 24, 25, 27, 30, 31, 38, 42, 48, 49, 53, 54, 55, 56, 60, 61, 65, 69, 70, 73])
# Out:
# Reading C:\Users\Alberto\Documents\BCI\data\eva\nirs_epo.fif ...
#     Found the data of interest:
#         t =   -4992.00 ...   19968.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 76 matching events found
# No baseline correction applied
# 0 projection items activated
# Dropped 32 epochs: 1, 3, 4, 7, 8, 9, 12, 15, 17, 18, 19, 21, 22, 24, 25, 27, 30, 31, 38, 42, 48, 49, 53, 54, 55, 56, 60, 61, 65, 69, 70, 73
# <EpochsFIF |  44 events (all good), -4.992 - 19.968 sec, baseline -3 – 0 sec, ~2.7 MB, data loaded,
#  'left': 8
#  'right': 11
#  'r_pinch': 7
#  'rest': 10
#  'r_stop': 8>

# %%
ica = ICA(n_components=2)
ica.fit(epochs)
# Out:
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# Selecting by number: 2 components
# Fitting ICA took 0.0s.
# C:\Users\Alberto\AppData\Local\Temp\ipykernel_10084\299129115.py:2: RuntimeWarning: The epochs you passed to ICA.fit() were baseline-corrected. However, we suggest to fit ICA only on data that has been high-pass filtered, but NOT baseline-corrected.
#   ica.fit(epochs)
# <ICA | epochs decomposition, method: fastica (fit in 2 iterations on 8624 samples), 2 ICA components (2 PCA components available), channel types: hbo, hbr, no sources marked for exclusion>

# %%
ica.plot_properties(
    epochs['left','right'].copy().crop(-3,15), 
    log_scale = False)
print()
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows
# C:\Users\Alberto\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mne\channels\layout.py:1115: RuntimeWarning: invalid value encountered in divide
#   i_dim /= (i_dim.max(0) - i_dim.min(0))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 ica.plot_properties(
#       2     epochs['left','right'].copy().crop(-3,15),
#       3     log_scale = False)
#       4 print()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mne\preprocessing\ica.py:2202, in ICA.plot_properties(self, inst, picks, axes, dB, plot_std, log_scale, topomap_args, image_args, psd_args, figsize, show, reject, reject_by_annotation, verbose)
#    2196 @copy_function_doc_to_method_doc(plot_ica_properties)
#    2197 def plot_properties(self, inst, picks=None, axes=None, dB=True,
#    2198                     plot_std=True, log_scale=False, topomap_args=None,
#    2199                     image_args=None, psd_args=None, figsize=None,
#    2200                     show=True, reject='auto', reject_by_annotation=True,
#    2201                     *, verbose=None):
# -> 2202     return plot_ica_properties(self, inst, picks=picks, axes=axes,
#    2203                                dB=dB, plot_std=plot_std,
#    2204                                log_scale=log_scale,
#    2205                                topomap_args=topomap_args,
#    2206                                image_args=image_args, psd_args=psd_args,
#    2207                                figsize=figsize, show=show, reject=reject,
#    2208                                reject_by_annotation=reject_by_annotation,
#    2209                                verbose=verbose)
#
# File <decorator-gen-163>:12, in plot_ica_properties(ica, inst, picks, axes, dB, plot_std, log_scale, topomap_args, image_args, psd_args, figsize, show, reject, reject_by_annotation, verbose)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mne\viz\ica.py:392, in plot_ica_properties(ica, inst, picks, axes, dB, plot_std, log_scale, topomap_args, image_args, psd_args, figsize, show, reject, reject_by_annotation, verbose)
#     309 @verbose
#     310 def plot_ica_properties(ica, inst, picks=None, axes=None, dB=True,
#     311                         plot_std=True, log_scale=False, topomap_args=None,
#     312                         image_args=None, psd_args=None, figsize=None,
#     313                         show=True, reject='auto', reject_by_annotation=True,
#     314                         *, verbose=None):
#     315     """Display component properties.
#     316
#     317     Properties include the topography, epochs image, ERP/ERF, power
#    (...)
#     390     .. versionadded:: 0.13
#     391     """
# --> 392     return _fast_plot_ica_properties(ica, inst, picks=picks, axes=axes, dB=dB,
#     393                                      plot_std=plot_std, log_scale=log_scale,
#     394                                      topomap_args=topomap_args,
#     395                                      image_args=image_args, psd_args=psd_args,
#     396                                      figsize=figsize, show=show,
#     397                                      reject=reject,
#     398                                      reject_by_annotation=reject_by_annotation,
#     399                                      verbose=verbose, precomputed_data=None)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mne\viz\ica.py:511, in _fast_plot_ica_properties(ica, inst, picks, axes, dB, plot_std, log_scale, topomap_args, image_args, psd_args, figsize, show, reject, precomputed_data, reject_by_annotation, verbose)
#     505     epoch_var = np.insert(arr=epoch_var,
#     506                           obj=drop_indices_corrected,
#     507                           values=drop_var[dropped_indices],
#     508                           axis=0)
#     510     # the actual plot
# --> 511     fig = _plot_ica_properties(
#     512         pick, ica, inst, psds_mean, freqs, ica_data.shape[1],
#     513         epoch_var, plot_lowpass_edge, epochs_src,
#     514         set_title_and_labels, plot_std, psd_ylabel, spectrum_std,
#     515         log_scale, topomap_args, image_args, fig, axes, kind,
#     516         dropped_indices)
#     517     all_fig.append(fig)
#     519 plt_show(show)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mne\viz\ica.py:155, in _plot_ica_properties(pick, ica, inst, psds_mean, freqs, n_trials, epoch_var, plot_lowpass_edge, epochs_src, set_title_and_labels, plot_std, psd_ylabel, spectrum_std, log_scale, topomap_args, image_args, fig, axes, kind, dropped_indices)
#     150 topo_ax, image_ax, erp_ax, spec_ax, var_ax = axes
#     152 # plotting
#     153 # --------
#     154 # component topomap
# --> 155 _plot_ica_topomap(ica, pick, show=False, axes=topo_ax, **topomap_args)
#     156 topo_ax._ch_type = _get_ch_type(ica, ch_type=None,
#     157                                 allow_ref_meg=ica.allow_ref_meg)
#     159 # image and erp
#     160 # we create a new epoch with dropped rows
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mne\viz\topomap.py:1125, in _plot_ica_topomap(ica, idx, ch_type, res, vmin, vmax, cmap, colorbar, title, show, outlines, contours, image_interp, axes, sensors, allow_ref_meg, extrapolate, sphere, border)
#    1123 axes.set_title(topo_title, fontsize=12)
#    1124 vlim = _setup_vmin_vmax(data, vmin, vmax)
# -> 1125 im = plot_topomap(
#    1126     data.ravel(), pos, vlim=vlim, res=res, axes=axes,
#    1127     cmap=cmap, outlines=outlines, contours=contours, sensors=sensors,
#    1128     image_interp=image_interp, show=show, extrapolate=extrapolate,
#    1129     sphere=sphere, border=border, ch_type=ch_type)[0]
#    1130 if colorbar:
#    1131     cbar, cax = _add_colorbar(axes, im, cmap, pad=.05, title="AU",
#    1132                               format='%3.2f')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mne\viz\topomap.py:824, in plot_topomap(data, pos, ch_type, sensors, show_names, names, mask, mask_params, contours, outlines, sphere, image_interp, extrapolate, border, res, size, cmap, vlim, vmin, vmax, cnorm, axes, show, onselect)
#     821 if cnorm is not None and (vlim[0] is not None or vlim[1] is not None):
#     822     warn(f'Provided cnorm implicitly defines vmin={cnorm.vmin} and '
#     823          f'vmax={cnorm.vmax}; ignoring additional vlim/vmin/vmax params.')
# --> 824 return _plot_topomap(
#     825     data, pos, vmin=vlim[0], vmax=vlim[1], cmap=cmap, sensors=sensors,
#     826     res=res, axes=axes, names=names, mask=mask, mask_params=mask_params,
#     827     outlines=outlines, contours=contours, image_interp=image_interp,
#     828     show=show, onselect=onselect, extrapolate=extrapolate, sphere=sphere,
#     829     border=border, ch_type=ch_type, cnorm=cnorm)[:2]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mne\viz\topomap.py:1013, in _plot_topomap(data, pos, axes, ch_type, sensors, names, mask, mask_params, contours, outlines, sphere, image_interp, extrapolate, border, res, cmap, vmin, vmax, cnorm, show, onselect)
#    1010 mask_params = _handle_default('mask_params', mask_params)
#    1012 # find mask limits and setup interpolation
# -> 1013 extent, Xi, Yi, interp = _setup_interp(
#    1014     pos, res, image_interp, extrapolate, outlines, border)
#    1015 interp.set_values(data)
#    1016 Zi = interp.set_locations(Xi, Yi)()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mne\viz\topomap.py:864, in _setup_interp(pos, res, image_interp, extrapolate, outlines, border)
#     862 yi = np.linspace(ymin, ymax, res)
#     863 Xi, Yi = np.meshgrid(xi, yi)
# --> 864 interp = _GridData(pos, image_interp, extrapolate,
#     865                    clip_origin, clip_radius, border)
#     866 extent = (xmin, xmax, ymin, ymax)
#     867 return extent, Xi, Yi, interp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mne\viz\topomap.py:659, in _GridData.__init__(self, pos, image_interp, extrapolate, origin, radii, border)
#     656     _check_option('border', border, ('mean',), extra='when a string')
#     658 # Adding points outside the extremes helps the interpolators
# --> 659 outer_pts, mask_pts, tri = _get_extra_points(
#     660     pos, extrapolate, origin, radii)
#     661 self.n_extra = outer_pts.shape[0]
#     662 self.mask_pts = mask_pts
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mne\viz\topomap.py:541, in _get_extra_points(pos, extrapolate, origin, radii)
#     539 with np.errstate(divide='ignore'):
#     540     slopes = diffs[:, 1] / diffs[:, 0]
# --> 541 colinear = ((slopes == slopes[0]).all() or np.isinf(slopes).all())
#     543 # compute median inter-electrode distance
#     544 if colinear or pos.shape[0] < 4:
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
ica.apply(epochs, exclude=[2,6,7])
# Out:
# Applying ICA to Epochs instance
#     Transforming to ICA space (8 components)
#     Zeroing out 3 ICA components
#     Projecting back using 26 PCA components
# C:\Users\Alberto\AppData\Local\Temp\ipykernel_8396\41852026.py:1: RuntimeWarning: The data you passed to ICA.apply() was baseline-corrected. Please note that ICA can introduce DC shifts, therefore you may wish to consider baseline-correcting the cleaned data again.
#   ica.apply(epochs, exclude=[2,6,7])
# <EpochsFIF |  82 events (all good), -4.992 - 19.968 sec, baseline -3 – 0 sec, ~5.0 MB, data loaded,
#  'left': 17
#  'right': 17
#  'r_pinch': 17
#  'rest': 16
#  'r_stop': 15>

# %%
epochs.plot(n_epochs=3, n_channels=20, scalings=80e-6, events=epochs.events, event_id=epochs.event_id)
print()
# Out:
# <MNEBrowseFigure size 1920x1017 with 4 Axes>

# %%
epochs['left','right'].copy().crop(-3,20).plot_image(combine='mean', vmin=-30, vmax=30,
                             ts_args=dict(ylim=dict(hbo=[-15, 15],
                                                    hbr=[-15, 15])))
# Out:
# Not setting metadata
# 19 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 19 matching events found
# No baseline correction applied
# 0 projection items activated
# combining channels using "mean"
# C:\Users\Alberto\AppData\Local\Temp\ipykernel_10084\3322461124.py:1: RuntimeWarning: tmax is not in time interval. tmax is set to <class 'mne.epochs.EpochsFIF'>.tmax (19.968 sec)
#   epochs['left','right'].copy().crop(-3,20).plot_image(combine='mean', vmin=-30, vmax=30,
# C:\Users\Alberto\AppData\Local\Temp\ipykernel_10084\3322461124.py:1: RuntimeWarning: Only one channel in group "hbr"; cannot combine by method "mean".
#   epochs['left','right'].copy().crop(-3,20).plot_image(combine='mean', vmin=-30, vmax=30,
# C:\Users\Alberto\AppData\Local\Temp\ipykernel_10084\3322461124.py:1: RuntimeWarning: Only one channel in group "hbo"; cannot combine by method "mean".
#   epochs['left','right'].copy().crop(-3,20).plot_image(combine='mean', vmin=-30, vmax=30,
# C:\Users\Alberto\AppData\Local\Temp\ipykernel_10084\3322461124.py:1: RuntimeWarning: Only 1 channel in "picks"; cannot combine by method "mean".
#   epochs['left','right'].copy().crop(-3,20).plot_image(combine='mean', vmin=-30, vmax=30,
# combining channels using "mean"
# C:\Users\Alberto\AppData\Local\Temp\ipykernel_10084\3322461124.py:1: RuntimeWarning: Only 1 channel in "picks"; cannot combine by method "mean".
#   epochs['left','right'].copy().crop(-3,20).plot_image(combine='mean', vmin=-30, vmax=30,
# [<Figure size 640x480 with 3 Axes>, <Figure size 640x480 with 3 Axes>]

# %%
epochs['rest'].copy().crop(-3,20).plot_image(combine='mean', vmin=-30, vmax=30,
                             ts_args=dict(ylim=dict(hbo=[-15, 15],
                                                    hbr=[-15, 15])))
# Out:
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# 0 projection items activated
# combining channels using "mean"
# C:\Users\Alberto\AppData\Local\Temp\ipykernel_10084\809773090.py:1: RuntimeWarning: tmax is not in time interval. tmax is set to <class 'mne.epochs.EpochsFIF'>.tmax (19.968 sec)
#   epochs['rest'].copy().crop(-3,20).plot_image(combine='mean', vmin=-30, vmax=30,
# C:\Users\Alberto\AppData\Local\Temp\ipykernel_10084\809773090.py:1: RuntimeWarning: Only one channel in group "hbr"; cannot combine by method "mean".
#   epochs['rest'].copy().crop(-3,20).plot_image(combine='mean', vmin=-30, vmax=30,
# C:\Users\Alberto\AppData\Local\Temp\ipykernel_10084\809773090.py:1: RuntimeWarning: Only one channel in group "hbo"; cannot combine by method "mean".
#   epochs['rest'].copy().crop(-3,20).plot_image(combine='mean', vmin=-30, vmax=30,
# C:\Users\Alberto\AppData\Local\Temp\ipykernel_10084\809773090.py:1: RuntimeWarning: Only 1 channel in "picks"; cannot combine by method "mean".
#   epochs['rest'].copy().crop(-3,20).plot_image(combine='mean', vmin=-30, vmax=30,
# combining channels using "mean"
# C:\Users\Alberto\AppData\Local\Temp\ipykernel_10084\809773090.py:1: RuntimeWarning: Only 1 channel in "picks"; cannot combine by method "mean".
#   epochs['rest'].copy().crop(-3,20).plot_image(combine='mean', vmin=-30, vmax=30,
# [<Figure size 640x480 with 3 Axes>, <Figure size 640x480 with 3 Axes>]

# %%
epochs.save('nirs_epo.fif',overwrite=True)
# Out:
# Overwriting existing file.
